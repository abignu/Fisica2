# %%
import numpy as np
from scipy.optimize import newton

# %%
#funcion a optimizar
def f(B):
  return 3*B + 2*B**2 + B**3 - B**5 - 2*B**6

# %%
solucion = newton(f, 2)
print(solucion)
# Out:
# 1.1908042643291252
