# %%
import numpy as np
from numpy import log2

# %%
#declaro probabilidades --> son 6
p = np.array(6)

# %%
#funcion a optimizar de la forma siguiente:
#L = (- p[0]*log2(p[0])- p[1]*log2(p[1])- p[2]*log2(p[2])- p[3]*log2(p[3])- p[4]*log2(p[4])
# - p[5]*log2(p[5])) - beta *(p[0]+p[1]+p[2]+p[3]+p[4]+p[5])

def L(p, beta):
  p1 = p[0]
  p2 = p[1]
  p3 = p[2]
  p4 = p[3]
  p5 = p[4]
  p6 = p[5]
  
  return (- p1*log2(p1)- p2*log2(p2)- p3*log2(p3)- p4*log2(p4)- p5*log2(p5) - p6*log2(p6)) - beta *(p1+p2+p3+p4+p5+p6)
